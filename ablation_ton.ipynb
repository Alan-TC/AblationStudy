# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import utils_inpynb as ut

# %% [markdown]
# ### Analise

# %%
df_ablation = pd.read_csv('ablation/ton/results/ablation.csv')
df_ablation.set_index('test_idx', inplace=True)
df_ablation.head()
# Out:
#           seed  n_iter  batch_size  n_units_hidden  flowmiagan_auc  \
# test_idx
# 1            1      50          50              32        0.595106
# 2            1      50          50              64        0.563843
# 3            1      50          50             128        0.581826
# 4            1      50         100              32        0.432041
# 5            1      50         100              64        0.260689
#
#           domias_auc   dcr_auc  accuracy  precision    recall  f1-score
# test_idx
# 1           0.609728  0.745287  0.990077   0.992468  0.983091  0.987641
# 2           0.321292  0.795104  0.998538   0.997748  0.998651  0.998199
# 3           0.800378  0.788613  0.997923   0.997479  0.997396  0.997438
# 4           0.191571  0.612937  0.988462   0.991099  0.980478  0.985611
# 5           0.550880  0.722564  0.997538   0.996076  0.997872  0.996969

# %%
ut.mean_std_grid_search_matrix(df_ablation, 'n_units_hidden', 'batch_size', 'n_iter', ['f1-score', 'dcr_auc', 'domias_auc', 'flowmiagan_auc'])
